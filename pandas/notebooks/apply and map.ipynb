# %%
import pandas as pd
df = pd.read_csv('wine.csv')
df.head(3)
# Out:
#    Unnamed: 0   country                                        description  \
# 0           0     Italy  Aromas include tropical fruit, broom, brimston...
# 1           1  Portugal  This is ripe and fruity, a wine that is smooth...
# 2           2        US  Tart and snappy, the flavors of lime flesh and...
#
#     designation  points  price           province           region_1  \
# 0  Vulkà Bianco      87    NaN  Sicily & Sardinia               Etna
# 1      Avidagos      87   15.0              Douro                NaN
# 2           NaN      87   14.0             Oregon  Willamette Valley
#
#             region_2    taster_name taster_twitter_handle  \
# 0                NaN  Kerin O’Keefe          @kerinokeefe
# 1                NaN     Roger Voss            @vossroger
# 2  Willamette Valley   Paul Gregutt           @paulgwine
#
#                                            title         variety  \
# 0              Nicosia 2013 Vulkà Bianco  (Etna)     White Blend
# 1  Quinta dos Avidagos 2011 Avidagos Red (Douro)  Portuguese Red
# 2  Rainstorm 2013 Pinot Gris (Willamette Valley)      Pinot Gris
#
#                 winery
# 0              Nicosia
# 1  Quinta dos Avidagos
# 2            Rainstorm

# %%
df.price.map(lambda a: a - 10.0)
# can also map values to numbers. ex. map male to 1 and female to 0
# df['map genders'] = df.gender.map({'male': 1, 'female': 0})
# Out:
# 0          NaN
# 1          5.0
# 2          4.0
# 3          3.0
# 4         55.0
#           ...
# 129966    18.0
# 129967    65.0
# 129968    20.0
# 129969    22.0
# 129970    11.0
# Name: price, Length: 129970, dtype: float64

# %%
# create new colum with length of strings in description
df['length country'] = df.description.apply(len)
df.loc[:, ['country', 'length country']]
# Out:
#          country  length country
# 0          Italy             172
# 1       Portugal             227
# 2             US             186
# 3             US             199
# 4             US             249
# ...          ...             ...
# 129966   Germany             227
# 129967        US             233
# 129968    France             225
# 129969    France             216
# 129970    France             169
#
# [129971 rows x 2 columns]

# %%
# variety has 1 missing value so cannot get first word
df.isnull().sum()
# Out:
# Unnamed: 0                   0
# country                     63
# description                  0
# designation              37465
# points                       0
# price                     8996
# province                    63
# region_1                 21247
# region_2                 79460
# taster_name              26244
# taster_twitter_handle    31213
# title                        0
# variety                      1
# winery                       0
# length country               0
# dtype: int64

# %%
df.dropna(subset = ['variety'], inplace = True)

# %%
# variety now has 0 missing values
df.isnull().sum()
# Out:
# Unnamed: 0                   0
# country                     63
# description                  0
# designation              37464
# points                       0
# price                     8996
# province                    63
# region_1                 21246
# region_2                 79459
# taster_name              26243
# taster_twitter_handle    31212
# title                        0
# variety                      0
# winery                       0
# length country               0
# dtype: int64

# %%
# get first word from variety column and sotre in first word column
df['first word'] = df.variety.str.split(" ").apply(lambda a : a[0]).head()
df[['variety', 'first word']]
# Out:
#                variety  first word
# 0          White Blend       White
# 1       Portuguese Red  Portuguese
# 2           Pinot Gris       Pinot
# 3             Riesling    Riesling
# 4           Pinot Noir       Pinot
# ...                ...         ...
# 129966        Riesling         NaN
# 129967      Pinot Noir         NaN
# 129968  Gewürztraminer         NaN
# 129969      Pinot Gris         NaN
# 129970  Gewürztraminer         NaN
#
# [129970 rows x 2 columns]

# %%
# remove missing values from first character column
df.dropna(subset = ['first word'], inplace = True)

# %%
# can use your own apply function
def get_first_character(s, position):
    return s[position]

# %%
df['first char'] = df['first word'].apply(get_first_character, position = 0)
df.loc[:, ['first word', 'first char']]
# Out:
#    first word first char
# 0       White          W
# 1  Portuguese          P
# 2       Pinot          P
# 3    Riesling          R
# 4       Pinot          P

# %%
df2 = df[['points', 'price']].iloc[1:13]
df2.head()
# Out:
#    points  price
# 1      87   15.0
# 2      87   14.0
# 3      87   13.0
# 4      87   65.0
# 5      87   15.0

# %%
# can also use apply as a dataframe method 
# choose the axis, axis 0 is default
# this get's the max values across each column
df2.apply(max)
# Out:
# points    87.0
# price     65.0
# min       65.0
# max        NaN
# dtype: float64

# %%
# this gets the max across each row
df2.apply(max, axis = 1)
# Out:
# 1     87.0
# 2     87.0
# 3     87.0
# 4     87.0
# 5     87.0
# 6     87.0
# 7     87.0
# 8     87.0
# 9     87.0
# 10    87.0
# 11    87.0
# 12    87.0
# dtype: float64

# %%
# apply map is a dataframe method that doesn't apply across an axis but rather across the entire map
# change every value in df to float
df2.applymap(float)
# Out:
#     points  price   min  max
# 1     87.0   15.0  15.0  NaN
# 2     87.0   14.0  14.0  NaN
# 3     87.0   13.0  13.0  NaN
# 4     87.0   65.0  65.0  NaN
# 5     87.0   15.0  15.0  NaN
# 6     87.0   16.0  16.0  NaN
# 7     87.0   24.0  24.0  NaN
# 8     87.0   12.0  12.0  NaN
# 9     87.0   27.0  27.0  NaN
# 10    87.0   19.0  19.0  NaN
# 11    87.0   30.0  30.0  NaN
# 12    87.0   34.0  34.0  NaN
